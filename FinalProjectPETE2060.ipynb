# %%
import numpy as np
import pandas as pd
import seaborn as sn
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'C:\Users\Devin Fryar\Downloads\project_data.csv')
print (df)
# Out:
#               Rst        SGoil      SGgas  Psp    Tsp
# 0         scf/STB  Sgwater=1.0  SGair=1.0  PSI  deg F
# 1     1.608311631          0.8        0.6   15     70
# 2     11.90248659         0.61       0.88   69     72
# 3      10.6736522         0.58       0.66   80     62
# 4      7.70841785         0.88       0.81  199     88
# 5     4.341078559         0.76       0.62   86    122
# 6     13.21936011         0.61       0.74  141     95
# 7     6.911217789         0.83       0.83  124     90
# 8     4.483643127          0.9       0.82   82     86
# 9     4.225543993         0.67       0.73   36    135
# 10    10.43997082          0.7       0.66  154     53
# 11    3.849951469         0.87       0.86   45     73
# 12    7.797083612         0.65       0.81   72    131
# 13    2.751423939         0.86        0.6   51     69
# 14    9.271696094         0.69       0.68  159    102
# 15    8.908925529         0.64       0.78   80    101
# ...

# %%
df
# Out:
#               Rst SGoil SGgas  Psp  Tsp
# 1     1.608311631   0.8   0.6   15   70
# 2     11.90248659  0.61  0.88   69   72
# 3      10.6736522  0.58  0.66   80   62
# 4      7.70841785  0.88  0.81  199   88
# 5     4.341078559  0.76  0.62   86  122
# 6     13.21936011  0.61  0.74  141   95
# 7     6.911217789  0.83  0.83  124   90
# 8     4.483643127   0.9  0.82   82   86
# 9     4.225543993  0.67  0.73   36  135
# 10    10.43997082   0.7  0.66  154   53
# 11    3.849951469  0.87  0.86   45   73
# 12    7.797083612  0.65  0.81   72  131
# 13    2.751423939  0.86   0.6   51   69
# 14    9.271696094  0.69  0.68  159  102
# 15    8.908925529  0.64  0.78   80  101
# 16     6.67257748  0.82   0.8  153  139
# 17    4.541862019  0.86  0.81   69   81
# 18    4.354997527   0.8  0.62  100  108
# 19     4.08354849   0.9  0.65  109   77
# 20    13.99214832  0.67  0.81  142   57
# 21    8.955666159  0.65  0.65  145  126
# 22    15.73783058  0.61  0.89  151  129
# ...

# %%
df.dtypes
# Out:
# Rst      object
# SGoil    object
# SGgas    object
# Psp      object
# Tsp      object
# dtype: object

# %%
df['Rst'] = df.Rst.astype(float)
df['SGoil'] = df.SGoil.astype(float)
df['SGgas'] = df.SGgas.astype(float)
df['Psp'] = df.Psp.astype(float)
df['Tsp'] = df.Tsp.astype(float)

# %%
plt.boxplot(df['Rst'])
plt.annotate('      Largest value within 1.5*IQR',[1,np.max(df['Rst'])])
plt.annotate('         Third Quartile',[1,np.percentile(df['Rst'], 75)])
plt.annotate('         First Quartile',[1,np.percentile(df['Rst'], 25)])
plt.annotate('         Median',[1,np.median(df['Rst'])])
plt.annotate('      Smallest value within 1.5*IQR',[1,np.min(df['Rst'])])
plt.show()

# %%
df.dtypes
# Out:
# Rst      float64
# SGoil    float64
# SGgas    float64
# Psp      float64
# Tsp      float64
# dtype: object

# %%
df.describe()
# Out:
#                Rst        SGoil        SGgas          Psp          Tsp
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      7.436124     0.743520     0.741680   107.629000    94.852000
# std       3.777297     0.097124     0.094335    54.240164    25.797279
# min       1.351996     0.580000     0.580000    15.000000    50.000000
# 25%       4.646156     0.660000     0.660000    63.750000    72.000000
# 50%       6.766796     0.750000     0.740000   108.000000    94.000000
# 75%       9.519505     0.830000     0.820000   153.000000   117.000000
# max      22.163125     0.900000     0.900000   200.000000   140.000000

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# Rst       4.873349
# SGoil     0.170000
# SGgas     0.160000
# Psp      89.250000
# Tsp      45.000000
# dtype: float64

# %%
print(df < (Q1 - 1.5 * IQR))
print(df > (Q3 + 1.5 * IQR))
# Out:
#         Rst  SGoil  SGgas    Psp    Tsp
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# 5     False  False  False  False  False
# 6     False  False  False  False  False
# 7     False  False  False  False  False
# 8     False  False  False  False  False
# 9     False  False  False  False  False
# 10    False  False  False  False  False
# 11    False  False  False  False  False
# 12    False  False  False  False  False
# 13    False  False  False  False  False
# 14    False  False  False  False  False
# 15    False  False  False  False  False
# 16    False  False  False  False  False
# 17    False  False  False  False  False
# 18    False  False  False  False  False
# 19    False  False  False  False  False
# 20    False  False  False  False  False
# 21    False  False  False  False  False
# 22    False  False  False  False  False
# ...

# %%
df.shape
# Out:
# (1000, 5)

# %%
df_out = df[~((df<(Q1-1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_out.shape
# Out:
# (974, 5)

# %%
df.plot.scatter("SGoil", "Rst")

# %%
df.plot.scatter("SGoil", "Rst")

# %%
df.plot.scatter("SGgas", "Rst")
plt.show()

# %%
df.plot.scatter("Psp", "Rst")
plt.show()

# %%
df.plot.scatter ("Tsp", "Rst")

# %%
Rst = df['Rst']
SGoil = df['SGoil']
plt.scatter(Rst, SGoil , edgecolors='g')
plt.ylabel('SGoil')
plt.xlabel('Rst')
plt.title('SGoil v. Rst')
plt.show()

# %%
Rst = df['Rst']
SGgas = df['SGgas']
plt.scatter(Rst, SGgas , edgecolors='y')
plt.ylabel('SGgas')
plt.xlabel('Rst')
plt.title('SGgas v. Rst')
plt.show()

# %%
Rst = df['Rst']
Psp = df['Psp']
plt.scatter(Rst, Psp , edgecolors='r')
plt.ylabel('Psp')
plt.xlabel('Rst')
plt.title('Psp v. Rst')
plt.show()

# %%
Rst = df['Rst']
Tsp = df['Tsp']
plt.scatter(Rst, Tsp , edgecolors='b')
plt.ylabel('Tsp')
plt.xlabel('Rst')
plt.title('Tsp v. Rst')
plt.show()

# %%
df['log_Psp']=np.log(df.Psp)
df['log_Tsp']=np.log(df.Tsp)
df['log_Rst']=np.log(df.Rst)
df['log_SGoil']=np.log(df.SGoil)
df['log_SGgas']=np.log(df.SGgas)
df
# Out:
#             Rst  SGoil  SGgas    Psp    Tsp   log_Psp   log_Tsp   log_Rst  \
# 1      1.608312   0.80   0.60   15.0   70.0  2.708050  4.248495  0.475185
# 2     11.902487   0.61   0.88   69.0   72.0  4.234107  4.276666  2.476747
# 3     10.673652   0.58   0.66   80.0   62.0  4.382027  4.127134  2.367778
# 4      7.708418   0.88   0.81  199.0   88.0  5.293305  4.477337  2.042313
# 5      4.341079   0.76   0.62   86.0  122.0  4.454347  4.804021  1.468123
# 6     13.219360   0.61   0.74  141.0   95.0  4.948760  4.553877  2.581682
# 7      6.911218   0.83   0.83  124.0   90.0  4.820282  4.499810  1.933146
# 8      4.483643   0.90   0.82   82.0   86.0  4.406719  4.454347  1.500436
# 9      4.225544   0.67   0.73   36.0  135.0  3.583519  4.905275  1.441148
# 10    10.439971   0.70   0.66  154.0   53.0  5.036953  3.970292  2.345642
# 11     3.849951   0.87   0.86   45.0   73.0  3.806662  4.290459  1.348061
# 12     7.797084   0.65   0.81   72.0  131.0  4.276666  4.875197  2.053750
# ...

# %%
plt.scatter(df.log_Psp,df.log_Rst)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(df.log_Tsp,df.log_Rst)
plt.show()

# %%
plt.scatter(df.log_SGoil,df.log_Rst)
plt.show()

# %%
import statsmodels.formula.api as smf

# %%
from sklearn import linear_model

# %%
X = df[['log_SGoil','log_SGgas','log_Psp','log_Tsp']]

Y = df['log_Rst']

regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  0.3817999999770654
# Coefficients:
#  [-2.39122542  1.26032259  0.57630878 -0.31942359]
#                             OLS Regression Results
# ...
# Dep. Variable:                log_Rst   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.438e+21
# Date:                Fri, 03 May 2019   Prob (F-statistic):               0.00
# Time:                        12:28:03   Log-Likelihood:                 21388.
# No. Observations:                1000   AIC:                        -4.277e+04
# Df Residuals:                     995   BIC:                        -4.274e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # y=-2.39122542x1+1.26032259x2+0.57630878x3-0.31942359x4+.3817999999770654
